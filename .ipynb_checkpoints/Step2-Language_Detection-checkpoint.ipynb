# %% [markdown]
# # Language Identification
#
# ## By character encoding

# %%
import pandas as pd

# %%
with open('Data/Significance_of_festivals_in_India.txt', 'r',encoding="utf-8") as myfile:
    data=myfile.read().replace('\n', '')

# %%
tokens = data.split(' ')

# %%
tokens
# Out:
# ['त्योहारों',
#  'का',
#  'होना',
#  'किसी',
#  'देश',
#  'के',
#  'लिए',
#  'महत्वपूर्ण',
#  'कितना',
#  'हैं?',
#  'बहुत',
#  'महत्वपूर्ण',
#  'हैं।',
#  'हर',
#  'महीने',
#  'एक',
#  'छुट्टी',
#  'मिलती',
#  'हैं।',
#  'उसके',
#  'अलावा?',
#  'उसके',
#  'अलावा',
#  'त्योहार',
#  'बहुत',
#  'ही',
#  'important',
#  'होते',
#  'हैं',
#  'कयोंकि',
#  '...',
#  'I',
#  'feel',
#  'की',
#  'मतलब',
#  'जिस',
#  'तरह',
#  'से',
#  'एक',
#  'chaos',
#  'मतलब,',
#  'work',
#  'culture',
#  'का',
#  'chaos',
#  'आज',
#  'कल',
#  'भारत',
#  'India',
#  'में',
#  'हैं',
#  'I',
#  'think',
#  'त्योहार',
#  'ही',
#  'ऐसी',
#  'चीज़',
#  'है',
#  'that',
#  'still',
#  'मतलब',
#  'binds',
#  'people',
#  'with',
#  'the',
#  'ancient',
#  'Indian',
#  'culture',
#  'तो',
#  'जो',
#  'Indian',
#  'culture',
#  'रहा',
#  'है',
#  'of',
#  'socializing',
#  'and',
#  'living',
#  'together',
#  'and',
#  'knowing',
#  'each',
#  'other',
#  'better',
#  'तो',
#  'वो',
#  'इन',
#  'त्योहारों',
#  'के',
#  'बलबुतें',
#  'पर',
#  'ही',
#  'टिका',
#  'हुआ',
#  'हैं',
#  'मुझे',
#  'ऐसा',
#  'लगता',
#  'हैं',
#  'that',
#  'is',
#  'still',
#  'what',
#  'binds',
#  'the',
#  'whole',
#  'of',
#  'India',
#  'together',
#  'त्योहार',
#  'होना',
#  'बहुत',
#  'ज़रुरी',
#  'हैं',
#  'कयोंकि',
#  'त्योहार',
#  'लोगों',
#  'को',
#  'करीब',
#  'लेकर',
#  'आता',
#  'हैं',
#  'त्योहार',
#  'एक,',
#  'कयोंकि',
#  'celebration..',
#  'त्योहार',
#  'का',
#  'दुसरा',
#  'नाम',
#  'celebration',
#  'है।',
#  'Celebration..',
#  'इनसान',
#  'को',
#  'celebrate',
#  'करना',
#  'काफ़ी',
#  'ज़रुरी',
#  'है।',
#  'इनसान',
#  'को',
#  'काफ़ी',
#  'चीज़ें',
#  'ज़्यादा',
#  'celebrate',
#  'करना',
#  'ज़रुरी',
#  'हैं',
#  'क्योंकि',
#  'वो',
#  'आपको',
#  'अपने',
#  'बारें',
#  'में',
#  'अच्छा',
#  'feel',
#  'करवाते',
#  'हैं',
#  'वो',
#  'अच्छीसी',
#  'feeling',
#  'देता',
#  'है',
#  'जो',
#  'आपको',
#  'आगे',
#  'motivate',
#  'करती',
#  'हैं',
#  'कुछ',
#  'और',
#  'करने',
#  'के',
#  'लिए',
#  'तो',
#  'हर',
#  'कुछ',
#  'period',
#  'में',
#  'त्योहार',
#  'आना',
#  'ज़रुरी',
#  'है',
#  'जो',
#  'की',
#  'भारत',
#  'में',
#  'होता',
#  'है',
#  'और',
#  'लोग',
#  'खुश',
#  'होतें',
#  'हैं',
#  'और',
#  'खुश',
#  'होने',
#  'की',
#  'वजह',
#  'से',
#  'काफ़ी',
#  'दुसरी',
#  'चीज़ें',
#  'होती',
#  'हैं',
#  'और',
#  'यह',
#  'काफ़ी',
#  'छोटी',
#  'चीज़',
#  'है,',
#  'मतलब,',
#  'अगर',
#  'आप',
#  'सुबह',
#  'उठते',
#  'हो',
#  'और',
#  'आप',
#  'खुश',
#  'हैं',
#  'तो',
#  'आपका',
#  'दिन',
#  'अच्छा',
#  'जाता',
#  'है',
#  'बिल्कुल',
#  'तो',
#  'हर',
#  'कुछ',
#  'बीस',
#  'पच्चीस',
#  'दिन',
#  'में',
#  'अगर',
#  'कोई',
#  'एक',
#  'त्योहार',
#  'आ',
#  'जाएँ,',
#  'और',
#  'आपके',
#  'पास',
#  'खुशी,',
#  'कुछ',
#  'ना',
#  'कुछ',
#  'मौका',
#  'हो',
#  'आपके',
#  'पास',
#  'अपनी',
#  'खुशी',
#  'celebrate',
#  'करने',
#  'का',
#  'तो',
#  'त्योहार',
#  'एक',
#  'मौके',
#  'की',
#  'तरह',
#  'होता',
#  'है',
#  'बीस',
#  'दिनों',
#  'में',
#  'कुछ',
#  'हुआ,',
#  'कुछ',
#  'अच्छी',
#  'चीज़ें',
#  'हुई',
#  'और',
#  'कुछ',
#  'बुरी',
#  'चीज़ें',
#  'हुई',
#  'तो',
#  'बुरी',
#  'चीज़ों',
#  'को',
#  'भुलाया',
#  'जाऐं',
#  'और',
#  'अच्छी',
#  'चीज़ों',
#  'को',
#  'याद',
#  'किया',
#  'जाएँ',
#  'और',
#  'उनके',
#  'बारें',
#  'में',
#  'खुश',
#  'हुआ',
#  'जाएँ',
#  'अपने',
#  'करीबी',
#  'लोगों',
#  'से',
#  'बात',
#  'की',
#  'जाऐं',
#  'इस',
#  'बारे',
#  'में',
#  'और',
#  'उन्हें',
#  'share',
#  'किया',
#  'जाएँ',
#  'अपनी',
#  'खुशी',
#  'को',
#  'share',
#  'किया',
#  'जाएँ',
#  'मिठाईयाँ',
#  'खाकर,',
#  'पटाकें',
#  'फोढ़कर,',
#  'रंग',
#  'से',
#  'खेलकर',
#  'कुछ',
#  'और',
#  'करके',
#  'इसी',
#  'लिए',
#  'त्योहार',
#  'बहुत',
#  'ही',
#  'ज़्यादा',
#  'ज़रुरी',
#  'हैं',
#  'क्योंकि',
#  'ऐसे',
#  'ऐसे',
#  'दिन',
#  'ज़्यादा',
#  'आएँ',
#  'क्योंकि',
#  'आप',
#  'चाहते',
#  'हैं',
#  'कि',
#  "Valentine's",
#  'day',
#  'बार',
#  'बार',
#  'आऐं',
#  'ताकि',
#  'आप',
#  'ज़्यादा',
#  'लढ़कियों',
#  'को',
#  'फूल',
#  'दे',
#  'सकें,',
#  'वैसे',
#  'ही',
#  'कुछ,',
#  'होली',
#  'के',
#  'दिन',
#  'ज़्यादा',
#  'आऐं',
#  'या',
#  'दिवाली',
#  'के',
#  'दिन',
#  'ज़्यादा',
#  'आएँ',
#  'या',
#  'फिर',
#  'ऐसे',
#  'ऐसे',
#  'दिन',
#  'ज़्यादा',
#  'आएँ',
#  'जहां',
#  'पर',
#  'आप',
#  'मिठाईयाँ',
#  'खा',
#  'सकें',
#  'आप',
#  'खुश',
#  'हो',
#  'सकें,',
#  'आप',
#  'अपने',
#  'लोगों',
#  'से',
#  'मिल',
#  'सकें,',
#  'उनसे',
#  'ज़्यादा',
#  'बात',
#  'कर',
#  'सकें',
#  'तो..',
#  'और',
#  'क्योंकि',
#  'इतने',
#  'सारे',
#  'लोगों',
#  'को',
#  'एक',
#  'साथ',
#  'ये',
#  'त्योहार',
#  'करीब',
#  'लातें',
#  'हैं,',
#  'बांधते',
#  'हैं',
#  'एक',
#  'साथ,',
#  'इसी',
#  'लिये',
#  'किसी',
#  'भी',
#  'देश',
#  'के',
#  'लिए',
#  'ये',
#  'बहुत',
#  'ज़रुरी',
#  'हैं,',
#  'उनके',
#  'लोगों',
#  'को',
#  'united',
#  'रखने',
#  'के',
#  'लिए',
#  'क्योंकि',
#  'अगर',
#  'बहुत',
#  'सारे',
#  'लोग',
#  'होली',
#  'या',
#  'दिवाली,',
#  'पूरा',
#  'भारत',
#  'मनाता',
#  'है।',
#  'तो',
#  'होली',
#  'या',
#  'दिवाली',
#  'के',
#  'दिन',
#  'भारतीय',
#  'सब',
#  'एक',
#  'साथ',
#  'हो',
#  'जाते',
#  'हैं',
#  'क्योंकि',
#  'सभी',
#  'लोग',
#  'एक',
#  'चीज़',
#  'कर',
#  'रहे',
#  'होते',
#  'हैं,',
#  'सभी',
#  'लोग',
#  'अपने',
#  'घरों',
#  'की',
#  'सफ़ाई',
#  'कर',
#  'रहे',
#  'होते',
#  'हैं,',
#  'या',
#  'फिर',
#  'मिठाईयाँ',
#  'खा',
#  'रहे',
#  'होतें',
#  'हैं',
#  'या',
#  'बना',
#  'रहे',
#  'होते',
#  'हैं',
#  'एक',
#  'खुशी',
#  'का',
#  'माहौल',
#  'सब',
#  'जगह',
#  'होता',
#  'है',
#  'और',
#  'आपके',
#  'पास',
#  'एक',
#  'common',
#  'बात',
#  'होती',
#  'है',
#  'हमेशा',
#  'किसी',
#  'ना',
#  'किसी',
#  'से,',
#  'हर',
#  'किसी',
#  'से',
#  'करने',
#  'की।',
#  'तो',
#  'त्योहार',
#  'लोगों',
#  'को',
#  'बांधतें',
#  'हैं,',
#  'उन्हें',
#  'करीब',
#  'लातें',
#  'हैं,',
#  'खुशी',
#  'देते',
#  'हैं,',
#  'तो',
#  'ये',
#  'बहुत',
#  'ज़रुरी',
#  'हैं।',
#  'यहीं',
#  'त्योहार',
#  'जब',
#  'आप',
#  'अमरीका',
#  'में',
#  'celebrate',
#  'करते',
#  'हो,',
#  'तो',
#  'क्या',
#  'अमेरिकन्स',
#  'उसे',
#  'अपनाते',
#  'हैं',
#  'और',
#  'उन्हें',
#  'खुशी',
#  'होतीं',
#  'हैं',
#  'आपके',
#  'साथ',
#  'उस',
#  'त्योहार',
#  'को',
#  'celebrate',
#  'करने',
#  'की?',
#  'मुझे',
#  'लगता',
#  'है',
#  'कि,',
#  'किसी',
#  'भी',
#  'इनसान',
#  'को',
#  'खुश',
#  'देखके',
#  'कोई',
#  'दुखी',
#  'नही',
#  'होता',
#  'और',
#  'खुशी',
#  'हमेशा...',
#  'अगर',
#  'आप',
#  'खुश',
#  'हैं',
#  'तो',
#  'आप',
#  'खुशी',
#  'बिखेरते',
#  'हैं',
#  'सब',
#  'अपने',
#  'आस',
#  'पास',
#  'तो',
#  'अगर',
#  'आप',
#  'खुश',
#  'हैं',
#  'तो',
#  'आप',
#  'सब',
#  'में',
#  'खुशी',
#  'बिखेरेंगें,',
#  'अगर',
#  'आप',
#  'हँस',
#  'रहे',
#  'हैं',
#  'और',
#  'आप',
#  'मतलब',
#  'खुश',
#  'हैं',
#  'और',
#  'मतलब',
#  'आपके',
#  'चेहरे',
#  'से',
#  'झलक',
#  'रही',
#  'हैं',
#  'बाते',
#  'तो',
#  'लोग',
#  'आपकी',
#  'तरफ़',
#  'attract',
#  'होंगे,',
#  'वो',
#  'आएंगे,',
#  'जानके',
#  'की',
#  'कोशिश',
#  'करेंगे',
#  'कि',
#  'आप',
#  'क्यों',
#  'खुश',
#  'हैं',
#  'और',
#  'आपसे',
#  'वो',
#  'share',
#  'करने',
#  'की',
#  'कोशिश',
#  'करेंगे',
#  'तो',
#  'अगर',
#  'मैं',
#  'यहां',
#  'पर',
#  'किसी',
#  'त्योहार',
#  'को',
#  'celebrate',
#  'करने',
#  'की',
#  'कोशिश',
#  'करुंगा',
#  'तो',
#  'अमरिकी',
#  'ही',
#  'क्या',
#  'किसी',
#  'भी',
#  'देश',
#  'के',
#  'लोग',
#  'खुश',
#  'ही',
#  'होंगे',
#  'अगर',
#  'वो',
#  'किसी',
#  'भी',
#  'तरह',
#  'से',
#  'उनके',
#  'against',
#  'नही',
#  'हैं',
#  'तो',
#  'अगर',
#  'वो',
#  'against',
#  'है',
#  'तो',
#  'जो',
#  'भी',
#  'religious,',
#  'political',
#  'reasons',
#  'हैं',
#  'तो',
#  'वो',
#  'अलग',
#  'हैं।',
#  'लेकिन',
#  'अगर',
#  'सिर्फ़',
#  'खुशी',
#  'की',
#  'तरह',
#  'देखा',
#  'जाए',
#  'तो',
#  'हाँ',
#  'अमरीकी',
#  'हमेशा',
#  'attract',
#  'होतें',
#  'हैं',
#  'वो',
#  'हमारे',
#  'साथ',
#  'वो',
#  'चीज़ें',
#  'करना',
#  'चाहते',
#  'हैं,',
#  'celebrate',
#  'करना',
#  'चाहते',
#  'हैं',
#  'क्योंकि',
#  'उनके',
#  'लिये',
#  'वो',
#  'नई',
#  'हैं',
#  'और',
#  'वो',
#  'एक',
#  'खुशी',
#  'का',
#  'ज़रिया',
#  'है',
#  'तो',
#  'वो',
#  'उसे',
#  'आगे',
#  'भी',
#  'करते',
#  'रेहना',
#  'चाहते',
#  'हैं',
#  'लेकिन',
#  'ज़्यादा',
#  'वो',
#  'इस',
#  'चीज़',
#  'पर',
#  'ध्यान',
#  'नही',
#  'देना',
#  'चाहते',
#  'है',
#  'कि',
#  'वो',
#  'त्योहार',
#  'क्यों',
#  'मनाया',
#  'जाता',
#  'है',
#  'या',
#  'कैसे',
#  'होता',
#  'है,',
#  'उन्हें',
#  'उस',
#  'से',
#  'फ़र्क',
#  'नही',
#  'पढ़ता',
#  'उन्हें',
#  'इस',
#  'से',
#  'फ़र्क',
#  'पढ़ता',
#  'है',
#  'कि',
#  'आप',
#  'इस',
#  'में',
#  'कितनी',
#  'मस्ती',
#  'कर',
#  'सकते',
#  'हो',
#  'आप',
#  'कितने',
#  'खुश',
#  'हो',
#  'सकते',
#  'हो,',
#  'आपके',
#  'पास',
#  'और',
#  'क्या',
#  'क्या',
#  'चीज़ें',
#  'हैं',
#  'और',
#  'नई',
#  'करने',
#  'के',
#  'लिए',
#  'क्योंकि',
#  'curiosity',
#  'एक',
#  'ऐसी',
#  'चीज़',
#  'है',
#  'जो',
#  'आपको',
#  'जानने',
#  'में',
#  'मजबूर',
#  'करती',
#  'है',
#  'सारी',
#  'चीज़ें',
#  'क्योंकि',
#  'आपको',
#  'कोई',
#  'चीज़',
#  'खुशी',
#  'देती',
#  'है',
#  'तो',
#  'उसके',
#  'source',
#  'को',
#  'हमेशा',
#  'जानने',
#  'की',
#  'आप',
#  'कोशिश',
#  'करते',
#  'हो',
#  'कि',
#  'क्या',
#  'है',
#  'ऐसी',
#  'बात।',
#  'रंग',
#  'खेलने',
#  'में',
#  'क्या',
#  'नया',
#  'है',
#  'या',
#  'पटाकें',
#  'फोढ़ने',
#  'में',
#  'क्या',
#  'नया',
#  'है',
#  'या',
#  'किसी',
#  'अलग',
#  'तरह',
#  'की',
#  'मिठाई',
#  'खाने',
#  'में',
#  'क्या',
#  'नया',
#  'है',
#  'कोई',
#  'नई',
#  'चीज़',
#  'अगर',
#  'आपको',
#  'अगर',
#  'खुशी',
#  'देती',
#  'है',
#  'तो',
#  'आप',
#  'उसे',
#  'बिल्कुल',
#  'करना',
#  'चाहोगे।',
#  'हाँ।',
#  'अगर',
#  'मैं',
#  'भारत',
#  'के',
#  'perspective',
#  'से',
#  'सोचु,',
#  'तो',
#  'मुझे',
#  'ये',
#  'लगता',
#  'है',
#  'कि',
#  'वहाँ',
#  'पर',
#  'इतने',
#  'religions',
#  'इतने',
#  'diverse',
#  'communities',
#  'हैं',
#  'लोगों',
#  'के..',
#  'कि,',
#  'वहाँ',
#  'पर',
#  'त्योहार',
#  'ही',
#  'हैं',
#  'जो',
#  'एक',
#  'दुसरे',
#  'को',
#  'बांध',
#  'सकते',
#  'हैं',
#  'जो',
#  'unity',
#  'एक',
#  'देश',
#  'में',
#  'आनी',
#  'ज़रुरी',
#  'है,',
#  'और',
#  'जो',
#  'होनी',
#  'चाहिए',
#  'वो',
#  'उन',
#  'त्योहारों',
#  'के',
#  'through',
#  'ही',
#  'आती',
#  'है।',
#  'और',
#  'मैंने',
#  'ये',
#  'देखा',
#  'है',
#  'कि',
#  'जब',
#  'हम',
#  'यहाँ',
#  'आते',
#  'हैं,',
#  'तो',
#  'वो',
#  'त्योहार',
#  'हम',
#  'लोग',
#  'खुद',
#  'तो',
#  'मनाते',
#  'ही',
#  'हैं,',
#  'और',
#  'बहुत',
#  'से',
#  'अमेरिकन',
#  'और',
#  'विदेशी',
#  'लोग',
#  'जो',
#  'यहाँ',
#  'रेहते',
#  'हैं',
#  'वो',
#  'भी',
#  'हमारे',
#  'साथ',
#  'मनाते',
#  'है।',
#  'तो',
#  'वो',
#  'मुझे',
#  'बहुत',
#  'अच्छा',
#  'लगता',
#  'है।',
#  'होली,',
#  'दिवाली',
#  'या',
#  'ईद',
#  'हुई,',
#  'और',
#  ...]

# %%
#tokens[2]
#type(tokens[2]) # str
#type(token.encode(encoding='utf-8')) # bytes
#tokens[39].encode(encoding='utf-8') # b'chaos'
tokens[2].encode(encoding='utf-8').decode('ascii') # 'chaos'
#tokens[5].encode(encoding='utf-8').decode('ascii')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-13-0fadb15e8d87> in <module>()
#       3 #type(token.encode(encoding='utf-8')) # bytes
#       4 #tokens[39].encode(encoding='utf-8') # b'chaos'
# ----> 5 tokens[2].encode(encoding='utf-8').decode('ascii') # 'chaos'
#       6 #tokens[5].encode(encoding='utf-8').decode('ascii')
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe0 in position 0: ordinal not in range(128)

# %%
lang_tags = []

for token in tokens:
    try:
        token.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        lang_tags.append("Hin")
    else:
       lang_tags.append("Eng")

# %%
for x, y in zip(tokens, lang_tags):
    print(x, y)
# Out:
# त्योहारों Hin
# का Hin
# होना Hin
# किसी Hin
# देश Hin
# के Hin
# लिए Hin
# महत्वपूर्ण Hin
# कितना Hin
# हैं? Hin
# बहुत Hin
# महत्वपूर्ण Hin
# हैं। Hin
# हर Hin
# महीने Hin
# एक Hin
# छुट्टी Hin
# मिलती Hin
# हैं। Hin
# उसके Hin
# अलावा? Hin
# उसके Hin
# अलावा Hin
# त्योहार Hin
# बहुत Hin
# ही Hin
# important Eng
# होते Hin
# हैं Hin
# कयोंकि Hin
# ... Eng
# I Eng
# feel Eng
# की Hin
# मतलब Hin
# जिस Hin
# तरह Hin
# से Hin
# एक Hin
# chaos Eng
# मतलब, Hin
# work Eng
# culture Eng
# का Hin
# chaos Eng
# आज Hin
# कल Hin
# भारत Hin
# India Eng
# में Hin
# हैं Hin
# I Eng
# think Eng
# त्योहार Hin
# ही Hin
# ऐसी Hin
# चीज़ Hin
# है Hin
# that Eng
# still Eng
# मतलब Hin
# binds Eng
# people Eng
# with Eng
# the Eng
# ancient Eng
# Indian Eng
# culture Eng
# तो Hin
# जो Hin
# Indian Eng
# culture Eng
# रहा Hin
# है Hin
# of Eng
# socializing Eng
# and Eng
# living Eng
# together Eng
# and Eng
# knowing Eng
# each Eng
# other Eng
# better Eng
# तो Hin
# वो Hin
# इन Hin
# त्योहारों Hin
# के Hin
# बलबुतें Hin
# पर Hin
# ही Hin
# टिका Hin
# हुआ Hin
# हैं Hin
# मुझे Hin
# ऐसा Hin
# लगता Hin
# हैं Hin
# that Eng
# is Eng
# still Eng
# what Eng
# binds Eng
# the Eng
# whole Eng
# of Eng
# India Eng
# together Eng
# त्योहार Hin
# होना Hin
# बहुत Hin
# ज़रुरी Hin
# हैं Hin
# कयोंकि Hin
# त्योहार Hin
# लोगों Hin
# को Hin
# करीब Hin
# लेकर Hin
# आता Hin
# हैं Hin
# त्योहार Hin
# एक, Hin
# कयोंकि Hin
# celebration.. Eng
# त्योहार Hin
# का Hin
# दुसरा Hin
# नाम Hin
# celebration Eng
# है। Hin
# Celebration.. Eng
# इनसान Hin
# को Hin
# celebrate Eng
# करना Hin
# काफ़ी Hin
# ज़रुरी Hin
# है। Hin
# इनसान Hin
# को Hin
# काफ़ी Hin
# चीज़ें Hin
# ज़्यादा Hin
# celebrate Eng
# करना Hin
# ज़रुरी Hin
# हैं Hin
# क्योंकि Hin
# वो Hin
# आपको Hin
# अपने Hin
# बारें Hin
# में Hin
# अच्छा Hin
# feel Eng
# करवाते Hin
# हैं Hin
# वो Hin
# अच्छीसी Hin
# feeling Eng
# देता Hin
# है Hin
# जो Hin
# आपको Hin
# आगे Hin
# motivate Eng
# करती Hin
# हैं Hin
# कुछ Hin
# और Hin
# करने Hin
# के Hin
# लिए Hin
# तो Hin
# हर Hin
# कुछ Hin
# period Eng
# में Hin
# त्योहार Hin
# आना Hin
# ज़रुरी Hin
# है Hin
# जो Hin
# की Hin
# भारत Hin
# में Hin
# होता Hin
# है Hin
# और Hin
# लोग Hin
# खुश Hin
# होतें Hin
# हैं Hin
# और Hin
# खुश Hin
# होने Hin
# की Hin
# वजह Hin
# से Hin
# काफ़ी Hin
# दुसरी Hin
# चीज़ें Hin
# होती Hin
# हैं Hin
# और Hin
# यह Hin
# काफ़ी Hin
# छोटी Hin
# चीज़ Hin
# है, Hin
# मतलब, Hin
# अगर Hin
# आप Hin
# सुबह Hin
# उठते Hin
# हो Hin
# और Hin
# आप Hin
# खुश Hin
# हैं Hin
# तो Hin
# आपका Hin
# दिन Hin
# अच्छा Hin
# जाता Hin
# है Hin
# बिल्कुल Hin
# तो Hin
# हर Hin
# कुछ Hin
# बीस Hin
# पच्चीस Hin
# दिन Hin
# में Hin
# अगर Hin
# कोई Hin
# एक Hin
# त्योहार Hin
# आ Hin
# जाएँ, Hin
# और Hin
# आपके Hin
# पास Hin
# खुशी, Hin
# कुछ Hin
# ना Hin
# कुछ Hin
# मौका Hin
# हो Hin
# आपके Hin
# पास Hin
# अपनी Hin
# खुशी Hin
# celebrate Eng
# करने Hin
# का Hin
# तो Hin
# त्योहार Hin
# एक Hin
# मौके Hin
# की Hin
# तरह Hin
# होता Hin
# है Hin
# बीस Hin
# दिनों Hin
# में Hin
# कुछ Hin
# हुआ, Hin
# कुछ Hin
# अच्छी Hin
# चीज़ें Hin
# हुई Hin
# और Hin
# कुछ Hin
# बुरी Hin
# चीज़ें Hin
# हुई Hin
# तो Hin
# बुरी Hin
# चीज़ों Hin
# को Hin
# भुलाया Hin
# जाऐं Hin
# और Hin
# अच्छी Hin
# चीज़ों Hin
# को Hin
# याद Hin
# किया Hin
# जाएँ Hin
# और Hin
# उनके Hin
# बारें Hin
# में Hin
# खुश Hin
# हुआ Hin
# जाएँ Hin
# अपने Hin
# करीबी Hin
# लोगों Hin
# से Hin
# बात Hin
# की Hin
# जाऐं Hin
# इस Hin
# बारे Hin
# में Hin
# और Hin
# उन्हें Hin
# share Eng
# किया Hin
# जाएँ Hin
# अपनी Hin
# खुशी Hin
# को Hin
# share Eng
# किया Hin
# जाएँ Hin
# मिठाईयाँ Hin
# खाकर, Hin
# पटाकें Hin
# फोढ़कर, Hin
# रंग Hin
# से Hin
# खेलकर Hin
# कुछ Hin
# और Hin
# करके Hin
# इसी Hin
# लिए Hin
# त्योहार Hin
# बहुत Hin
# ही Hin
# ज़्यादा Hin
# ज़रुरी Hin
# हैं Hin
# क्योंकि Hin
# ऐसे Hin
# ऐसे Hin
# दिन Hin
# ज़्यादा Hin
# आएँ Hin
# क्योंकि Hin
# आप Hin
# चाहते Hin
# हैं Hin
# कि Hin
# Valentine's Eng
# day Eng
# बार Hin
# बार Hin
# आऐं Hin
# ताकि Hin
# आप Hin
# ज़्यादा Hin
# लढ़कियों Hin
# को Hin
# फूल Hin
# दे Hin
# सकें, Hin
# वैसे Hin
# ही Hin
# कुछ, Hin
# होली Hin
# के Hin
# दिन Hin
# ज़्यादा Hin
# आऐं Hin
# या Hin
# दिवाली Hin
# के Hin
# दिन Hin
# ज़्यादा Hin
# आएँ Hin
# या Hin
# फिर Hin
# ऐसे Hin
# ऐसे Hin
# दिन Hin
# ज़्यादा Hin
# आएँ Hin
# जहां Hin
# पर Hin
# आप Hin
# मिठाईयाँ Hin
# खा Hin
# सकें Hin
# आप Hin
# खुश Hin
# हो Hin
# सकें, Hin
# आप Hin
# अपने Hin
# लोगों Hin
# से Hin
# मिल Hin
# सकें, Hin
# उनसे Hin
# ज़्यादा Hin
# बात Hin
# कर Hin
# सकें Hin
# तो.. Hin
# और Hin
# क्योंकि Hin
# इतने Hin
# सारे Hin
# लोगों Hin
# को Hin
# एक Hin
# साथ Hin
# ये Hin
# त्योहार Hin
# करीब Hin
# लातें Hin
# हैं, Hin
# बांधते Hin
# हैं Hin
# एक Hin
# साथ, Hin
# इसी Hin
# लिये Hin
# किसी Hin
# भी Hin
# देश Hin
# के Hin
# लिए Hin
# ये Hin
# बहुत Hin
# ज़रुरी Hin
# हैं, Hin
# उनके Hin
# लोगों Hin
# को Hin
# united Eng
# रखने Hin
# के Hin
# लिए Hin
# क्योंकि Hin
# अगर Hin
# बहुत Hin
# सारे Hin
# लोग Hin
# होली Hin
# या Hin
# दिवाली, Hin
# पूरा Hin
# भारत Hin
# मनाता Hin
# है। Hin
# तो Hin
# होली Hin
# या Hin
# दिवाली Hin
# के Hin
# दिन Hin
# भारतीय Hin
# सब Hin
# एक Hin
# साथ Hin
# हो Hin
# जाते Hin
# हैं Hin
# क्योंकि Hin
# सभी Hin
# लोग Hin
# एक Hin
# चीज़ Hin
# कर Hin
# रहे Hin
# होते Hin
# हैं, Hin
# सभी Hin
# लोग Hin
# अपने Hin
# घरों Hin
# की Hin
# सफ़ाई Hin
# कर Hin
# रहे Hin
# होते Hin
# हैं, Hin
# या Hin
# फिर Hin
# मिठाईयाँ Hin
# खा Hin
# रहे Hin
# होतें Hin
# हैं Hin
# या Hin
# बना Hin
# रहे Hin
# होते Hin
# हैं Hin
# एक Hin
# खुशी Hin
# का Hin
# माहौल Hin
# सब Hin
# जगह Hin
# होता Hin
# है Hin
# और Hin
# आपके Hin
# पास Hin
# एक Hin
# common Eng
# बात Hin
# होती Hin
# है Hin
# हमेशा Hin
# किसी Hin
# ना Hin
# किसी Hin
# से, Hin
# हर Hin
# किसी Hin
# से Hin
# करने Hin
# की। Hin
# तो Hin
# त्योहार Hin
# लोगों Hin
# को Hin
# बांधतें Hin
# हैं, Hin
# उन्हें Hin
# करीब Hin
# लातें Hin
# हैं, Hin
# खुशी Hin
# देते Hin
# हैं, Hin
# तो Hin
# ये Hin
# बहुत Hin
# ज़रुरी Hin
# हैं। Hin
# यहीं Hin
# त्योहार Hin
# जब Hin
# आप Hin
# अमरीका Hin
# में Hin
# celebrate Eng
# करते Hin
# हो, Hin
# तो Hin
# क्या Hin
# अमेरिकन्स Hin
# उसे Hin
# अपनाते Hin
# हैं Hin
# और Hin
# उन्हें Hin
# खुशी Hin
# होतीं Hin
# हैं Hin
# आपके Hin
# साथ Hin
# उस Hin
# त्योहार Hin
# को Hin
# celebrate Eng
# करने Hin
# की? Hin
# मुझे Hin
# लगता Hin
# है Hin
# कि, Hin
# किसी Hin
# भी Hin
# इनसान Hin
# को Hin
# खुश Hin
# देखके Hin
# कोई Hin
# दुखी Hin
# नही Hin
# होता Hin
# और Hin
# खुशी Hin
# हमेशा... Hin
# अगर Hin
# आप Hin
# खुश Hin
# हैं Hin
# तो Hin
# आप Hin
# खुशी Hin
# बिखेरते Hin
# हैं Hin
# सब Hin
# अपने Hin
# आस Hin
# पास Hin
# तो Hin
# अगर Hin
# आप Hin
# खुश Hin
# हैं Hin
# तो Hin
# आप Hin
# सब Hin
# में Hin
# खुशी Hin
# बिखेरेंगें, Hin
# अगर Hin
# आप Hin
# हँस Hin
# रहे Hin
# हैं Hin
# और Hin
# आप Hin
# मतलब Hin
# खुश Hin
# हैं Hin
# और Hin
# मतलब Hin
# आपके Hin
# चेहरे Hin
# से Hin
# झलक Hin
# रही Hin
# हैं Hin
# बाते Hin
# तो Hin
# लोग Hin
# आपकी Hin
# तरफ़ Hin
# attract Eng
# होंगे, Hin
# वो Hin
# आएंगे, Hin
# जानके Hin
# की Hin
# कोशिश Hin
# करेंगे Hin
# कि Hin
# आप Hin
# क्यों Hin
# खुश Hin
# हैं Hin
# और Hin
# आपसे Hin
# वो Hin
# share Eng
# करने Hin
# की Hin
# कोशिश Hin
# करेंगे Hin
# तो Hin
# अगर Hin
# मैं Hin
# यहां Hin
# पर Hin
# किसी Hin
# त्योहार Hin
# को Hin
# celebrate Eng
# करने Hin
# की Hin
# कोशिश Hin
# करुंगा Hin
# तो Hin
# अमरिकी Hin
# ही Hin
# क्या Hin
# किसी Hin
# भी Hin
# देश Hin
# के Hin
# लोग Hin
# खुश Hin
# ही Hin
# होंगे Hin
# अगर Hin
# वो Hin
# किसी Hin
# भी Hin
# तरह Hin
# से Hin
# उनके Hin
# against Eng
# नही Hin
# हैं Hin
# तो Hin
# अगर Hin
# वो Hin
# against Eng
# है Hin
# तो Hin
# जो Hin
# भी Hin
# religious, Eng
# political Eng
# reasons Eng
# हैं Hin
# तो Hin
# वो Hin
# अलग Hin
# हैं। Hin
# लेकिन Hin
# अगर Hin
# सिर्फ़ Hin
# खुशी Hin
# की Hin
# तरह Hin
# देखा Hin
# जाए Hin
# तो Hin
# हाँ Hin
# अमरीकी Hin
# हमेशा Hin
# attract Eng
# होतें Hin
# हैं Hin
# वो Hin
# हमारे Hin
# साथ Hin
# वो Hin
# चीज़ें Hin
# करना Hin
# चाहते Hin
# हैं, Hin
# celebrate Eng
# करना Hin
# चाहते Hin
# हैं Hin
# क्योंकि Hin
# उनके Hin
# लिये Hin
# वो Hin
# नई Hin
# हैं Hin
# और Hin
# वो Hin
# एक Hin
# खुशी Hin
# का Hin
# ज़रिया Hin
# है Hin
# तो Hin
# वो Hin
# उसे Hin
# आगे Hin
# भी Hin
# करते Hin
# रेहना Hin
# चाहते Hin
# हैं Hin
# लेकिन Hin
# ज़्यादा Hin
# वो Hin
# इस Hin
# चीज़ Hin
# पर Hin
# ध्यान Hin
# नही Hin
# देना Hin
# चाहते Hin
# है Hin
# कि Hin
# वो Hin
# त्योहार Hin
# क्यों Hin
# मनाया Hin
# जाता Hin
# है Hin
# या Hin
# कैसे Hin
# होता Hin
# है, Hin
# उन्हें Hin
# उस Hin
# से Hin
# फ़र्क Hin
# नही Hin
# पढ़ता Hin
# उन्हें Hin
# इस Hin
# से Hin
# फ़र्क Hin
# पढ़ता Hin
# है Hin
# कि Hin
# आप Hin
# इस Hin
# में Hin
# कितनी Hin
# मस्ती Hin
# कर Hin
# सकते Hin
# हो Hin
# आप Hin
# कितने Hin
# खुश Hin
# हो Hin
# सकते Hin
# हो, Hin
# आपके Hin
# पास Hin
# और Hin
# क्या Hin
# क्या Hin
# चीज़ें Hin
# हैं Hin
# और Hin
# नई Hin
# करने Hin
# के Hin
# लिए Hin
# क्योंकि Hin
# curiosity Eng
# एक Hin
# ऐसी Hin
# चीज़ Hin
# है Hin
# जो Hin
# आपको Hin
# जानने Hin
# में Hin
# मजबूर Hin
# करती Hin
# है Hin
# सारी Hin
# चीज़ें Hin
# क्योंकि Hin
# आपको Hin
# कोई Hin
# चीज़ Hin
# खुशी Hin
# देती Hin
# है Hin
# तो Hin
# उसके Hin
# source Eng
# को Hin
# हमेशा Hin
# जानने Hin
# की Hin
# आप Hin
# कोशिश Hin
# करते Hin
# हो Hin
# कि Hin
# क्या Hin
# है Hin
# ऐसी Hin
# बात। Hin
# रंग Hin
# खेलने Hin
# में Hin
# क्या Hin
# नया Hin
# है Hin
# या Hin
# पटाकें Hin
# फोढ़ने Hin
# में Hin
# क्या Hin
# नया Hin
# है Hin
# या Hin
# किसी Hin
# अलग Hin
# तरह Hin
# की Hin
# मिठाई Hin
# खाने Hin
# में Hin
# क्या Hin
# नया Hin
# है Hin
# कोई Hin
# नई Hin
# चीज़ Hin
# अगर Hin
# आपको Hin
# अगर Hin
# खुशी Hin
# देती Hin
# है Hin
# तो Hin
# आप Hin
# उसे Hin
# बिल्कुल Hin
# करना Hin
# चाहोगे। Hin
# हाँ। Hin
# अगर Hin
# मैं Hin
# भारत Hin
# के Hin
# perspective Eng
# से Hin
# सोचु, Hin
# तो Hin
# मुझे Hin
# ये Hin
# लगता Hin
# है Hin
# कि Hin
# वहाँ Hin
# पर Hin
# इतने Hin
# religions Eng
# इतने Hin
# diverse Eng
# communities Eng
# हैं Hin
# लोगों Hin
# के.. Hin
# कि, Hin
# वहाँ Hin
# पर Hin
# त्योहार Hin
# ही Hin
# हैं Hin
# जो Hin
# एक Hin
# दुसरे Hin
# को Hin
# बांध Hin
# सकते Hin
# हैं Hin
# जो Hin
# unity Eng
# एक Hin
# देश Hin
# में Hin
# आनी Hin
# ज़रुरी Hin
# है, Hin
# और Hin
# जो Hin
# होनी Hin
# चाहिए Hin
# वो Hin
# उन Hin
# त्योहारों Hin
# के Hin
# through Eng
# ही Hin
# आती Hin
# है। Hin
# और Hin
# मैंने Hin
# ये Hin
# देखा Hin
# है Hin
# कि Hin
# जब Hin
# हम Hin
# यहाँ Hin
# आते Hin
# हैं, Hin
# तो Hin
# वो Hin
# त्योहार Hin
# हम Hin
# लोग Hin
# खुद Hin
# तो Hin
# मनाते Hin
# ही Hin
# हैं, Hin
# और Hin
# बहुत Hin
# से Hin
# अमेरिकन Hin
# और Hin
# विदेशी Hin
# लोग Hin
# जो Hin
# यहाँ Hin
# रेहते Hin
# हैं Hin
# वो Hin
# भी Hin
# हमारे Hin
# साथ Hin
# मनाते Hin
# है। Hin
# तो Hin
# वो Hin
# मुझे Hin
# बहुत Hin
# अच्छा Hin
# लगता Hin
# है। Hin
# होली, Hin
# दिवाली Hin
# या Hin
# ईद Hin
# हुई, Hin
# और Hin
# जितने Hin
# भी Hin
# त्योहार Hin
# है Hin
# वो Hin
# सब Hin
# मनाए Hin
# जाते Hin
# हैं, Hin
# यहाँ Hin
# पे। Hin
# मुझे Hin
# लगता Hin
# है Hin
# कि Hin
# वो Hin
# एक Hin
# बहुत Hin
# अच्छा Hin
# समय Hin
# होता Hin
# है Hin
# दुसरे Hin
# लोगों Hin
# से Hin
# मिलने Hin
# का, Hin
# दुसरे Hin
# culture Eng
# को Hin
# समझने Hin
# का। Hin
# थैंक्स-गिविंग Hin
# या Hin
# क्रिस्मस, Hin
# जो Hin
# बचपन Hin
# से Hin
# मैंने Hin
# नही Hin
# मनाए Hin
# हैं Hin
# त्योहार, Hin
# पर Hin
# यहाँ Hin
# आके Hin
# मैं Hin
# मनाने Hin
# लगा Hin
# हूँ, Hin
# अपने Hin
# friends Eng
# दोस्तों Hin
# के Hin
# साथ Hin
# कुछ, Hin
# उनके Hin
# साथ Hin
# कुछ Hin
# activities Eng
# उन Hin
# त्योहारों Hin
# से Hin
# related Eng
# करने Hin
# लगा Hin
# हूँ Hin
# तो Hin
# वो Hin
# देखके Hin
# अच्छा Hin
# लगता Hin
# है। Hin
# और Hin
# लगता Hin
# है Hin
# कि Hin
# ऐसा Hin
# ही Hin
# होना Hin
# चाहिए Hin
# सब Hin
# त्योहार Hin
# मनाए Hin
# जाए, Hin
# और Hin
# हर Hin
# एक Hin
# religion Eng
# हर Hin
# एक Hin
# त्योहार Hin
# की Hin
# अपनी Hin
# importance Eng
# रहें। Hin
# जब Hin
# भी Hin
# मैंने Hin
# अपने Hin
# कुछ Hin
# और Hin
# दोस्तों Hin
# को Hin
# जो Hin
# विदेशी Hin
# हैं Hin
# या Hin
# अमेरिकन Hin
# हैं, Hin
# उन्हें Hin
# बुलाया Hin
# हैं Hin
# कि Hin
# आज Hin
# ये Hin
# त्योहार Hin
# है Hin
# ये Hin
# यहाँ Hin
# ऐसे Hin
# मनाया Hin
# जाएगा, Hin
# तो Hin
# उन्होंने Hin
# बहुत Hin
# खुशी Hin
# से, Hin
# वे Hin
# शामिल Hin
# हुए Hin
# हैं Hin
# हमारे Hin
# साथ। Hin
# तो Hin
# वे Hin
# बहुत Hin
# open-minded Eng
# और Hin
# accepting Eng
# रहे Hin
# हैं। Hin

# %%
from string import punctuation
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# ## Your turn / ¡Te toca!
# Create a function to take text and output a dataframe with two columns: Token and Language.
# Consider how to separate and label punctuation. Two options, create a separate "Punctuation" tag or tag with the previous language.

# %%
def language_id(text):
    # tokenize
    tokens = text.split(' ')
    new_tokens = []
    for token in tokens:
        if token[-1] in punctuation:
            new_tokens.append(token[:-1])
            new_tokens.append(token[:-1])
        else:
            new_tokens.append(token)
            
    # language tag

    for token in tokens:
    try:
        token.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        lang_tags.append("Hin")
    else:
       lang_tags.append("Eng")
    return

# %% [markdown]
# Explore the Hindi-English file
# What percentage is Hindi? English?
