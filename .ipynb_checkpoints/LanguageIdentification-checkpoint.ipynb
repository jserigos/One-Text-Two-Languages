# %% [markdown]
# # Unicode Files
# Checking to see how easy it is to process utf-8 formatted Hindi English

# %%
# Lets import modules needed
import sys
import math
import numpy as np
import pandas as pd
from itertools import groupby
from collections import Counter
import csv

# %%
with open('Data/Significance_of_festivals_in_India.txt', 'r',encoding="utf-8") as myfile:
    data=myfile.read().replace('\n', '')

# %%
tokens = data.split(' ')

# %%
tokens
# Out:
# ['\ufeffत्योहारों',
#  'का',
#  'होना',
#  'किसी',
#  'देश',
#  'के',
#  'लिए',
#  'महत्वपूर्ण',
#  'कितना',
#  'हैं?',
#  'बहुत',
#  'महत्वपूर्ण',
#  'हैं।',
#  'हर',
#  'महीने',
#  'एक',
#  'छुट्टी',
#  'मिलती',
#  'हैं।',
#  'उसके',
#  'अलावा?',
#  'उसके',
#  'अलावा',
#  'त्योहार',
#  'बहुत',
#  'ही',
#  'important',
#  'होते',
#  'हैं',
#  'कयोंकि',
#  '...',
#  'I',
#  'feel',
#  'की',
#  'मतलब',
#  'जिस',
#  'तरह',
#  'से',
#  'एक',
#  'chaos',
#  'मतलब,',
#  'work',
#  'culture',
#  'का',
#  'chaos',
#  'आज',
#  'कल',
#  'भारत',
#  'India',
#  'में',
#  'हैं',
#  'I',
#  'think',
#  'त्योहार',
#  'ही',
#  'ऐसी',
#  'चीज़',
#  'है',
#  'that',
#  'still',
#  'मतलब',
#  'binds',
#  'people',
#  'with',
#  'the',
#  'ancient',
#  'Indian',
#  'culture',
#  'तो',
#  'जो',
#  'Indian',
#  'culture',
#  'रहा',
#  'है',
#  'of',
#  'socializing',
#  'and',
#  'living',
#  'together',
#  'and',
#  'knowing',
#  'each',
#  'other',
#  'better',
#  'तो',
#  'वो',
#  'इन',
# ...

# %%
lang_tags = []
#i = 0
tokens = tokens[1:]
for token in tokens:
    t = ord(token[0])
    if (((t > 0x0041) and(t < 0x005A)) or ((t > 0x0061) and(t < 0x006A))):
       lang_tags.append("Eng")
    else:
       lang_tags.append("Hin")

# %%
lang_tags
# Out:
# ['Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Eng',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Eng',
#  'Eng',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Eng',
#  'Hin',
#  'Hin',
#  'Eng',
#  'Hin',
#  'Eng',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Eng',
#  'Hin',
#  'Hin',
#  'Eng',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Eng',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Eng',
#  'Eng',
#  'Hin',
#  'Hin',
#  'Eng',
#  'Eng',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Eng',
#  'Hin',
#  'Eng',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Hin',
#  'Eng',
# ...

# %%
df = pd.DataFrame(
    {'word': tokens,
     'language': lang_tags,
    })

# %%
df
# Out:
#              word language
# 0              का      Hin
# 1            होना      Hin
# 2            किसी      Hin
# 3             देश      Hin
# 4              के      Hin
# 5             लिए      Hin
# 6      महत्वपूर्ण      Hin
# 7           कितना      Hin
# 8            हैं?      Hin
# 9            बहुत      Hin
# 10     महत्वपूर्ण      Hin
# 11           हैं।      Hin
# 12             हर      Hin
# 13          महीने      Hin
# 14             एक      Hin
# 15         छुट्टी      Hin
# 16          मिलती      Hin
# 17           हैं।      Hin
# 18           उसके      Hin
# 19         अलावा?      Hin
# 20           उसके      Hin
# 21          अलावा      Hin
# 22        त्योहार      Hin
# 23           बहुत      Hin
# 24             ही      Hin
# 25      important      Eng
# 26           होते      Hin
# 27            हैं      Hin
# 28         कयोंकि      Hin
# 29            ...      Hin
# ...           ...      ...
# 1111          हैं      Hin
# 1112           कि      Hin
# ...
